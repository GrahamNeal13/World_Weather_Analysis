# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # current description of weather for city.
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | soyo
# Processing Record 2 of Set 16 | butaritari
# Processing Record 3 of Set 16 | thompson
# Processing Record 4 of Set 16 | kavieng
# Processing Record 5 of Set 16 | ilulissat
# Processing Record 6 of Set 16 | klaksvik
# Processing Record 7 of Set 16 | ponta delgada
# Processing Record 8 of Set 16 | lamu
# Processing Record 9 of Set 16 | atuona
# Processing Record 10 of Set 16 | berlevag
# Processing Record 11 of Set 16 | bethel
# Processing Record 12 of Set 16 | kodiak
# Processing Record 13 of Set 16 | gao
# Processing Record 14 of Set 16 | kitami
# Processing Record 15 of Set 16 | batemans bay
# Processing Record 16 of Set 16 | saint-philippe
# Processing Record 17 of Set 16 | grindavik
# Processing Record 18 of Set 16 | saldanha
# Processing Record 19 of Set 16 | katyuzhanka
# Processing Record 20 of Set 16 | tuktoyaktuk
# Processing Record 21 of Set 16 | norman wells
# Processing Record 22 of Set 16 | mount darwin
# Processing Record 23 of Set 16 | provideniya
# Processing Record 24 of Set 16 | sangar
# Processing Record 25 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 16 | bluff
# Processing Record 28 of Set 16 | saint-pierre
# Processing Record 29 of Set 16 | busselton
# Processing Record 30 of Set 16 | srednekolymsk
# Processing Record 31 of Set 16 | rikitea
# Processing Record 32 of Set 16 | lorengau
# Processing Record 33 of Set 16 | celestun
# Processing Record 34 of Set 16 | ushuaia
# Processing Record 35 of Set 16 | montepuez
# Processing Record 36 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 16 | mataura
# Processing Record 38 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 16 | avarua
# Processing Record 40 of Set 16 | jamestown
# Processing Record 41 of Set 16 | ribeira grande
# Processing Record 42 of Set 16 | cidreira
# Processing Record 43 of Set 16 | victoria
# Processing Record 44 of Set 16 | mar del plata
# Processing Record 45 of Set 16 | inirida
# Processing Record 46 of Set 16 | hermanus
# Processing Record 47 of Set 16 | ponta do sol
# Processing Record 48 of Set 16 | nkan
# Processing Record 49 of Set 16 | moron
# Processing Record 50 of Set 16 | isetskoye
# Processing Record 1 of Set 17 | madarounfa
# Processing Record 2 of Set 17 | wamba
# Processing Record 3 of Set 17 | vaini
# Processing Record 4 of Set 17 | cherskiy
# Processing Record 5 of Set 17 | kapaa
# Processing Record 6 of Set 17 | fort nelson
# Processing Record 7 of Set 17 | hopelchen
# Processing Record 8 of Set 17 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 17 | la palma
# Processing Record 10 of Set 17 | sistranda
# Processing Record 11 of Set 17 | cape town
# Processing Record 12 of Set 17 | limbang
# Processing Record 13 of Set 17 | burnie
# Processing Record 14 of Set 17 | port-gentil
# Processing Record 15 of Set 17 | ginir
# Processing Record 16 of Set 17 | anloga
# Processing Record 17 of Set 17 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 17 | leningradskiy
# Processing Record 19 of Set 17 | georgetown
# Processing Record 20 of Set 17 | ostrovnoy
# Processing Record 21 of Set 17 | pevek
# Processing Record 22 of Set 17 | harper
# Processing Record 23 of Set 17 | flinders
# Processing Record 24 of Set 17 | lagodekhi
# Processing Record 25 of Set 17 | yar-sale
# Processing Record 26 of Set 17 | khao yoi
# Processing Record 27 of Set 17 | severo-kurilsk
# Processing Record 28 of Set 17 | barrow
# Processing Record 29 of Set 17 | narrabri
# Processing Record 30 of Set 17 | lebu
# Processing Record 31 of Set 17 | vila franca do campo
# Processing Record 32 of Set 17 | ambilobe
# Processing Record 33 of Set 17 | albany
# Processing Record 34 of Set 17 | coihaique
# Processing Record 35 of Set 17 | puerto ayora
# Processing Record 36 of Set 17 | camacha
# Processing Record 37 of Set 17 | vila velha
# Processing Record 38 of Set 17 | nelson bay
# Processing Record 39 of Set 17 | asau
# Processing Record 40 of Set 17 | hithadhoo
# Processing Record 41 of Set 17 | biak
# Processing Record 42 of Set 17 | kangaatsiaq
# Processing Record 43 of Set 17 | kurilsk
# Processing Record 44 of Set 17 | port elizabeth
# Processing Record 45 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 17 | smithers
# Processing Record 47 of Set 17 | kroya
# Processing Record 48 of Set 17 | bima
# Processing Record 49 of Set 17 | kapoeta
# Processing Record 50 of Set 17 | port alfred
# Processing Record 1 of Set 18 | tautira
# Processing Record 2 of Set 18 | itamaraca
# Processing Record 3 of Set 18 | bolshiye uki
# City not found. Skipping...
# Processing Record 4 of Set 18 | lompoc
# Processing Record 5 of Set 18 | nome
# Processing Record 6 of Set 18 | abha
# Processing Record 7 of Set 18 | george
# Processing Record 8 of Set 18 | miyako
# Processing Record 9 of Set 18 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 18 | rio grande
# Processing Record 11 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 18 | saint-louis
# Processing Record 13 of Set 18 | new norfolk
# Processing Record 14 of Set 18 | calama
# Processing Record 15 of Set 18 | olga
# Processing Record 16 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 18 | hurghada
# Processing Record 18 of Set 18 | souillac
# Processing Record 19 of Set 18 | saint george
# Processing Record 20 of Set 18 | guilin
# Processing Record 21 of Set 18 | port hardy
# Processing Record 22 of Set 18 | bengkulu
# Processing Record 23 of Set 18 | moose factory
# Processing Record 24 of Set 18 | bandarbeyla
# Processing Record 25 of Set 18 | upernavik
# Processing Record 26 of Set 18 | zabol
# Processing Record 27 of Set 18 | pearl
# Processing Record 28 of Set 18 | mbalmayo
# Processing Record 29 of Set 18 | nabire
# Processing Record 30 of Set 18 | cockburn town
# Processing Record 31 of Set 18 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 18 | praia
# Processing Record 33 of Set 18 | lashio
# Processing Record 34 of Set 18 | longyearbyen
# Processing Record 35 of Set 18 | nikolskoye
# Processing Record 36 of Set 18 | grenaa
# Processing Record 37 of Set 18 | arraial do cabo
# Processing Record 38 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 18 | khatanga
# Processing Record 40 of Set 18 | amalapuram
# Processing Record 41 of Set 18 | isangel
# Processing Record 42 of Set 18 | zapolyarnyy
# Processing Record 43 of Set 18 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 18 | hobart
# Processing Record 45 of Set 18 | punta arenas
# Processing Record 46 of Set 18 | tuatapere
# Processing Record 47 of Set 18 | wajima
# Processing Record 48 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 18 | gotsu
# Processing Record 1 of Set 19 | prince rupert
# Processing Record 2 of Set 19 | hamadan
# Processing Record 3 of Set 19 | komsomolskiy
# Processing Record 4 of Set 19 | hilo
# Processing Record 5 of Set 19 | mapastepec
# Processing Record 6 of Set 19 | pangnirtung
# Processing Record 7 of Set 19 | saskylakh
# Processing Record 8 of Set 19 | fairbanks
# Processing Record 9 of Set 19 | nanortalik
# Processing Record 10 of Set 19 | honiara
# Processing Record 11 of Set 19 | gitarama
# Processing Record 12 of Set 19 | mahebourg
# Processing Record 13 of Set 19 | andenes
# Processing Record 14 of Set 19 | guatire
# Processing Record 15 of Set 19 | bow island
# Processing Record 16 of Set 19 | itarema
# Processing Record 17 of Set 19 | khandyga
# Processing Record 18 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 19 | tiksi
# Processing Record 20 of Set 19 | gorontalo
# Processing Record 21 of Set 19 | vilhena
# Processing Record 22 of Set 19 | tasiilaq
# Processing Record 23 of Set 19 | acuna
# City not found. Skipping...
# Processing Record 24 of Set 19 | sitka
# Processing Record 25 of Set 19 | kruisfontein
# Processing Record 26 of Set 19 | bredasdorp
# Processing Record 27 of Set 19 | lata
# Processing Record 28 of Set 19 | kahului
# Processing Record 29 of Set 19 | placido de castro
# Processing Record 30 of Set 19 | sterling
# Processing Record 31 of Set 19 | kavaratti
# Processing Record 32 of Set 19 | padang
# Processing Record 33 of Set 19 | bernalillo
# Processing Record 34 of Set 19 | krasnoselkup
# Processing Record 35 of Set 19 | kaitangata
# Processing Record 36 of Set 19 | bakel
# Processing Record 37 of Set 19 | noumea
# Processing Record 38 of Set 19 | morondava
# Processing Record 39 of Set 19 | bijar
# Processing Record 40 of Set 19 | cuenca
# Processing Record 41 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 19 | nema
# Processing Record 43 of Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 19 | geraldton
# Processing Record 45 of Set 19 | porto novo
# Processing Record 46 of Set 19 | hay river
# Processing Record 47 of Set 19 | lebyazhye
# Processing Record 48 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 19 | dikson
# Processing Record 50 of Set 19 | casa nova
# Processing Record 1 of Set 20 | ararat
# Processing Record 2 of Set 20 | mount gambier
# Processing Record 3 of Set 20 | dabola
# Processing Record 4 of Set 20 | raca
# Processing Record 5 of Set 20 | hovd
# Processing Record 6 of Set 20 | bonavista
# Processing Record 7 of Set 20 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 20 | marsa matruh
# Processing Record 9 of Set 20 | katsuura
# Processing Record 10 of Set 20 | marrakesh
# Processing Record 11 of Set 20 | carnarvon
# Processing Record 12 of Set 20 | gamba
# Processing Record 13 of Set 20 | olafsvik
# Processing Record 14 of Set 20 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 20 | xining
# Processing Record 16 of Set 20 | chokurdakh
# Processing Record 17 of Set 20 | okhotsk
# Processing Record 18 of Set 20 | baryatino
# Processing Record 19 of Set 20 | umm lajj
# Processing Record 20 of Set 20 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 20 | malangali
# Processing Record 22 of Set 20 | batagay
# Processing Record 23 of Set 20 | uribia
# Processing Record 24 of Set 20 | abeche
# Processing Record 25 of Set 20 | sambava
# Processing Record 26 of Set 20 | palmerston
# Processing Record 27 of Set 20 | beringovskiy
# Processing Record 28 of Set 20 | muros
# Processing Record 29 of Set 20 | husavik
# Processing Record 30 of Set 20 | nuuk
# Processing Record 31 of Set 20 | arica
# Processing Record 32 of Set 20 | kargasok
# Processing Record 33 of Set 20 | qaanaaq
# Processing Record 34 of Set 20 | grootfontein
# Processing Record 35 of Set 20 | fare
# Processing Record 36 of Set 20 | atlantic city
# Processing Record 37 of Set 20 | tartagal
# Processing Record 38 of Set 20 | college
# Processing Record 39 of Set 20 | airai
# Processing Record 40 of Set 20 | badarpur
# Processing Record 41 of Set 20 | faya
# Processing Record 42 of Set 20 | broken hill
# Processing Record 43 of Set 20 | kabanjahe
# Processing Record 44 of Set 20 | pimentel
# Processing Record 45 of Set 20 | hambantota
# Processing Record 46 of Set 20 | imbituba
# Processing Record 47 of Set 20 | pisco
# Processing Record 48 of Set 20 | hualmay
# Processing Record 49 of Set 20 | chuy
# Processing Record 50 of Set 20 | yumen
# Processing Record 1 of Set 21 | beruwala
# Processing Record 2 of Set 21 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 21 | luderitz
# Processing Record 4 of Set 21 | east london
# Processing Record 5 of Set 21 | villefranche-de-rouergue
# Processing Record 6 of Set 21 | orlik
# Processing Record 7 of Set 21 | mitchell
# Processing Record 8 of Set 21 | bunia
# Processing Record 9 of Set 21 | aklavik
# Processing Record 10 of Set 21 | valparaiso
# Processing Record 11 of Set 21 | nouadhibou
# Processing Record 12 of Set 21 | manokwari
# Processing Record 13 of Set 21 | ancud
# Processing Record 14 of Set 21 | vestmannaeyjar
# Processing Record 15 of Set 21 | tornio
# Processing Record 16 of Set 21 | tiarei
# Processing Record 17 of Set 21 | mezen
# Processing Record 18 of Set 21 | jalu
# Processing Record 19 of Set 21 | pareora
# Processing Record 20 of Set 21 | nizhniy tsasuchey
# Processing Record 21 of Set 21 | yatou
# Processing Record 22 of Set 21 | beberibe
# Processing Record 23 of Set 21 | dudinka
# Processing Record 24 of Set 21 | telsiai
# Processing Record 25 of Set 21 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 21 | yellowknife
# Processing Record 27 of Set 21 | havelock
# Processing Record 28 of Set 21 | turukhansk
# Processing Record 29 of Set 21 | hasaki
# Processing Record 30 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 21 | kerteh
# City not found. Skipping...
# Processing Record 32 of Set 21 | sakakah
# Processing Record 33 of Set 21 | monte azul
# Processing Record 34 of Set 21 | guerrero negro
# Processing Record 35 of Set 21 | guasdualito
# Processing Record 36 of Set 21 | rawson
# Processing Record 37 of Set 21 | havre-saint-pierre
# Processing Record 38 of Set 21 | santa vitoria do palmar
# Processing Record 39 of Set 21 | talnakh
# Processing Record 40 of Set 21 | hofn
# Processing Record 41 of Set 21 | nuevo progreso
# Processing Record 42 of Set 21 | puurmani
# Processing Record 43 of Set 21 | turtas
# Processing Record 44 of Set 21 | kirakira
# Processing Record 45 of Set 21 | olinda
# Processing Record 46 of Set 21 | east wenatchee bench
# Processing Record 47 of Set 21 | adrar
# Processing Record 48 of Set 21 | bahia blanca
# Processing Record 49 of Set 21 | yulara
# Processing Record 50 of Set 21 | torbay
# Processing Record 1 of Set 22 | tra vinh
# Processing Record 2 of Set 22 | williams lake
# Processing Record 3 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 22 | koumac
# Processing Record 5 of Set 22 | ubinskoye
# Processing Record 6 of Set 22 | inuvik
# Processing Record 7 of Set 22 | puerto escondido
# Processing Record 8 of Set 22 | oga
# Processing Record 9 of Set 22 | toropets
# Processing Record 10 of Set 22 | porosozero
# Processing Record 11 of Set 22 | bonnyville
# Processing Record 12 of Set 22 | puerto armuelles
# Processing Record 13 of Set 22 | bosaso
# Processing Record 14 of Set 22 | port shepstone
# Processing Record 15 of Set 22 | riyadh
# Processing Record 16 of Set 22 | kolyvan
# Processing Record 17 of Set 22 | haines junction
# Processing Record 18 of Set 22 | buraydah
# Processing Record 19 of Set 22 | san luis
# Processing Record 20 of Set 22 | along
# Processing Record 21 of Set 22 | zyryanovskiy
# City not found. Skipping...
# Processing Record 22 of Set 22 | khash
# Processing Record 23 of Set 22 | obera
# Processing Record 24 of Set 22 | portland
# Processing Record 25 of Set 22 | owensboro
# Processing Record 26 of Set 22 | broome
# Processing Record 27 of Set 22 | crestview
# Processing Record 28 of Set 22 | ciudad bolivar
# Processing Record 29 of Set 22 | uglich
# Processing Record 30 of Set 22 | nishihara
# Processing Record 31 of Set 22 | marsh harbour
# Processing Record 32 of Set 22 | port lincoln
# Processing Record 33 of Set 22 | gumdag
# Processing Record 34 of Set 22 | bilma
# Processing Record 35 of Set 22 | morro bay
# Processing Record 36 of Set 22 | tabou
# Processing Record 37 of Set 22 | salalah
# Processing Record 38 of Set 22 | carutapera
# Processing Record 39 of Set 22 | ternate
# Processing Record 40 of Set 22 | kangaba
# Processing Record 41 of Set 22 | pustoshka
# Processing Record 42 of Set 22 | pringsewu
# Processing Record 43 of Set 22 | kieta
# Processing Record 44 of Set 22 | bucsa
# Processing Record 45 of Set 22 | samarai
# Processing Record 46 of Set 22 | miracema do tocantins
# Processing Record 47 of Set 22 | antalaha
# Processing Record 48 of Set 22 | swift current
# Processing Record 49 of Set 22 | praia da vitoria
# Processing Record 50 of Set 22 | kryve ozero
# Processing Record 1 of Set 23 | kendari
# Processing Record 2 of Set 23 | kaoma
# Processing Record 3 of Set 23 | bathsheba
# Processing Record 4 of Set 23 | castro
# Processing Record 5 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 23 | tikapur
# Processing Record 7 of Set 23 | hailar
# Processing Record 8 of Set 23 | varna
# Processing Record 9 of Set 23 | southbridge
# Processing Record 10 of Set 23 | cabo san lucas
# Processing Record 11 of Set 23 | christchurch
# Processing Record 12 of Set 23 | serra branca
# Processing Record 13 of Set 23 | sioux lookout
# Processing Record 14 of Set 23 | constitucion
# Processing Record 15 of Set 23 | barranca
# Processing Record 16 of Set 23 | fulitun
# City not found. Skipping...
# Processing Record 17 of Set 23 | caraballeda
# Processing Record 18 of Set 23 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 23 | aykhal
# Processing Record 20 of Set 23 | kaduna
# Processing Record 21 of Set 23 | forbes
# Processing Record 22 of Set 23 | touros
# Processing Record 23 of Set 23 | krasnoborsk
# Processing Record 24 of Set 23 | poum
# Processing Record 25 of Set 23 | ariquemes
# Processing Record 26 of Set 23 | anar darreh
# City not found. Skipping...
# Processing Record 27 of Set 23 | robe
# Processing Record 28 of Set 23 | san jose
# Processing Record 29 of Set 23 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 23 | filadelfia
# Processing Record 31 of Set 23 | shingu
# Processing Record 32 of Set 23 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 23 | kota belud
# Processing Record 34 of Set 23 | carnduff
# Processing Record 35 of Set 23 | kuytun
# Processing Record 36 of Set 23 | iskateley
# Processing Record 37 of Set 23 | madera
# Processing Record 38 of Set 23 | pandan
# Processing Record 39 of Set 23 | maarianhamina
# Processing Record 40 of Set 23 | orapa
# Processing Record 41 of Set 23 | samana
# Processing Record 42 of Set 23 | honningsvag
# Processing Record 43 of Set 23 | iqaluit
# Processing Record 44 of Set 23 | nykoping
# Processing Record 45 of Set 23 | hamilton
# Processing Record 46 of Set 23 | avera
# Processing Record 47 of Set 23 | thinadhoo
# Processing Record 48 of Set 23 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 23 | la ronge
# Processing Record 50 of Set 23 | matara
# Processing Record 1 of Set 24 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 24 | turka
# Processing Record 3 of Set 24 | kungurtug
# Processing Record 4 of Set 24 | san ignacio
# Processing Record 5 of Set 24 | takoradi
# Processing Record 6 of Set 24 | kumluca
# Processing Record 7 of Set 24 | labe
# Processing Record 8 of Set 24 | galesong
# Processing Record 9 of Set 24 | baglan
# Processing Record 10 of Set 24 | buala
# Processing Record 11 of Set 24 | yinchuan
# Processing Record 12 of Set 24 | cervo
# Processing Record 13 of Set 24 | coahuayana
# Processing Record 14 of Set 24 | maku
# Processing Record 15 of Set 24 | bozhou
# Processing Record 16 of Set 24 | valle de allende
# Processing Record 17 of Set 24 | tateyama
# Processing Record 18 of Set 24 | sulangan
# Processing Record 19 of Set 24 | sola
# Processing Record 20 of Set 24 | quatre cocos
# Processing Record 21 of Set 24 | los llanos de aridane
# Processing Record 22 of Set 24 | siocon
# Processing Record 23 of Set 24 | japura
# Processing Record 24 of Set 24 | mafinga
# Processing Record 25 of Set 24 | port hedland
# Processing Record 26 of Set 24 | lasa
# Processing Record 27 of Set 24 | sapouy
# Processing Record 28 of Set 24 | san patricio
# Processing Record 29 of Set 24 | kachiry
# Processing Record 30 of Set 24 | verkhnevilyuysk
# Processing Record 31 of Set 24 | nadapuram
# Processing Record 32 of Set 24 | maraba
# Processing Record 33 of Set 24 | grand gaube
# Processing Record 34 of Set 24 | ekibastuz
# Processing Record 35 of Set 24 | waipawa
# Processing Record 36 of Set 24 | qorveh
# Processing Record 37 of Set 24 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 24 | tonantins
# Processing Record 39 of Set 24 | lodwar
# Processing Record 40 of Set 24 | ontario
# Processing Record 41 of Set 24 | clyde river
# Processing Record 42 of Set 24 | kirkenaer
# Processing Record 43 of Set 24 | vardo
# Processing Record 44 of Set 24 | saryg-sep
# Processing Record 45 of Set 24 | laguna
# Processing Record 46 of Set 24 | wanning
# Processing Record 47 of Set 24 | galle
# Processing Record 48 of Set 24 | ucluelet
# Processing Record 49 of Set 24 | maceio
# Processing Record 50 of Set 24 | lodja
# Processing Record 1 of Set 25 | kutum
# Processing Record 2 of Set 25 | careiro da varzea
# Processing Record 3 of Set 25 | neuquen
# Processing Record 4 of Set 25 | cody
# Processing Record 5 of Set 25 | eyl
# Processing Record 6 of Set 25 | puerto leguizamo
# Processing Record 7 of Set 25 | sandwick
# Processing Record 8 of Set 25 | farafangana
# Processing Record 9 of Set 25 | carauari
# Processing Record 10 of Set 25 | warrington
# Processing Record 11 of Set 25 | mecca
# Processing Record 12 of Set 25 | schwerin
# Processing Record 13 of Set 25 | preobrazheniye
# Processing Record 14 of Set 25 | anderson
# Processing Record 15 of Set 25 | wukari
# Processing Record 16 of Set 25 | cairns
# Processing Record 17 of Set 25 | palmer
# Processing Record 18 of Set 25 | werda
# Processing Record 19 of Set 25 | sorland
# Processing Record 20 of Set 25 | dalaba
# Processing Record 21 of Set 25 | san quintin
# Processing Record 22 of Set 25 | mayumba
# Processing Record 23 of Set 25 | anadyr
# Processing Record 24 of Set 25 | tucuma
# Processing Record 25 of Set 25 | adre
# Processing Record 26 of Set 25 | walvis bay
# Processing Record 27 of Set 25 | aybak
# City not found. Skipping...
# Processing Record 28 of Set 25 | qaqortoq
# Processing Record 29 of Set 25 | sita buzaului
# Processing Record 30 of Set 25 | tura
# Processing Record 31 of Set 25 | paamiut
# Processing Record 32 of Set 25 | cayenne
# Processing Record 33 of Set 25 | hailey
# Processing Record 34 of Set 25 | odweyne
# Processing Record 35 of Set 25 | esperance
# Processing Record 36 of Set 25 | mount isa
# Processing Record 37 of Set 25 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 25 | wonthaggi
# Processing Record 39 of Set 25 | severnyy
# Processing Record 40 of Set 25 | alberton
# Processing Record 41 of Set 25 | ulaangom
# Processing Record 42 of Set 25 | coventry
# Processing Record 43 of Set 25 | vila
# Processing Record 44 of Set 25 | lahij
# Processing Record 45 of Set 25 | port augusta
# Processing Record 46 of Set 25 | san andres
# Processing Record 47 of Set 25 | ayotzintepec
# Processing Record 48 of Set 25 | puerto del rosario
# Processing Record 49 of Set 25 | faanui
# Processing Record 50 of Set 25 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 26 | champerico
# Processing Record 2 of Set 26 | kenai
# Processing Record 3 of Set 26 | lavrentiya
# Processing Record 4 of Set 26 | cleethorpes
# Processing Record 5 of Set 26 | nizhnyaya poyma
# Processing Record 6 of Set 26 | lagoa
# Processing Record 7 of Set 26 | tulun
# Processing Record 8 of Set 26 | morristown
# Processing Record 9 of Set 26 | stillwater
# Processing Record 10 of Set 26 | izhma
# Processing Record 11 of Set 26 | port moresby
# Processing Record 12 of Set 26 | dolores
# Processing Record 13 of Set 26 | bobo dioulasso
# Processing Record 14 of Set 26 | thunder bay
# Processing Record 15 of Set 26 | san cristobal
# Processing Record 16 of Set 26 | hami
# Processing Record 17 of Set 26 | ugoofaaru
# Processing Record 18 of Set 26 | aripuana
# Processing Record 19 of Set 26 | marsaxlokk
# Processing Record 20 of Set 26 | scarborough
# Processing Record 21 of Set 26 | lar
# Processing Record 22 of Set 26 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 26 | ambanja
# Processing Record 24 of Set 26 | katsiveli
# City not found. Skipping...
# Processing Record 25 of Set 26 | laishevo
# Processing Record 26 of Set 26 | mpika
# Processing Record 27 of Set 26 | ilhabela
# Processing Record 28 of Set 26 | cabedelo
# Processing Record 29 of Set 26 | baculin
# Processing Record 30 of Set 26 | kiunga
# Processing Record 31 of Set 26 | barra do corda
# Processing Record 32 of Set 26 | dipkarpaz
# City not found. Skipping...
# Processing Record 33 of Set 26 | emerald
# Processing Record 34 of Set 26 | verkhoyansk
# Processing Record 35 of Set 26 | kununurra
# Processing Record 36 of Set 26 | chenzhou
# Processing Record 37 of Set 26 | san roque
# Processing Record 38 of Set 26 | hirara
# Processing Record 39 of Set 26 | dergachi
# Processing Record 40 of Set 26 | fallon
# Processing Record 41 of Set 26 | richards bay
# Processing Record 42 of Set 26 | kavarskas
# Processing Record 43 of Set 26 | negele
# City not found. Skipping...
# Processing Record 44 of Set 26 | zabid
# Processing Record 45 of Set 26 | churapcha
# Processing Record 46 of Set 26 | tecoanapa
# Processing Record 47 of Set 26 | benguela
# Processing Record 48 of Set 26 | araouane
# Processing Record 49 of Set 26 | fukue
# Processing Record 50 of Set 26 | saquena
# Processing Record 1 of Set 27 | annau
# Processing Record 2 of Set 27 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 27 | liverpool
# Processing Record 4 of Set 27 | colwyn bay
# Processing Record 5 of Set 27 | ondjiva
# Processing Record 6 of Set 27 | buta
# Processing Record 7 of Set 27 | eureka
# Processing Record 8 of Set 27 | omsukchan
# Processing Record 9 of Set 27 | zharkent
# Processing Record 10 of Set 27 | tynda
# Processing Record 11 of Set 27 | kautokeino
# Processing Record 12 of Set 27 | chernyshevskiy
# Processing Record 13 of Set 27 | vitim
# Processing Record 14 of Set 27 | decatur
# Processing Record 15 of Set 27 | shelburne
# Processing Record 16 of Set 27 | selma
# Processing Record 17 of Set 27 | kibala
# Processing Record 18 of Set 27 | kars
# Processing Record 19 of Set 27 | sheridan
# Processing Record 20 of Set 27 | chengde
# Processing Record 21 of Set 27 | beidao
# Processing Record 22 of Set 27 | coruripe
# Processing Record 23 of Set 27 | pangody
# Processing Record 24 of Set 27 | zarubino
# Processing Record 25 of Set 27 | pemangkat
# Processing Record 26 of Set 27 | sobolevo
# Processing Record 27 of Set 27 | edgewater
# Processing Record 28 of Set 27 | rio gallegos
# Processing Record 29 of Set 27 | taoudenni
# Processing Record 30 of Set 27 | boende
# Processing Record 31 of Set 27 | purpe
# Processing Record 32 of Set 27 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 27 | krivosheino
# Processing Record 34 of Set 27 | craigieburn
# Processing Record 35 of Set 27 | saint-joseph
# Processing Record 36 of Set 27 | trenggalek
# Processing Record 37 of Set 27 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 27 | itacare
# Processing Record 39 of Set 27 | namatanai
# Processing Record 40 of Set 27 | dubno
# Processing Record 41 of Set 27 | okhtyrka
# Processing Record 42 of Set 27 | vanimo
# Processing Record 43 of Set 27 | kandrian
# Processing Record 44 of Set 27 | russell
# Processing Record 45 of Set 27 | bambous virieux
# Processing Record 46 of Set 27 | kilindoni
# Processing Record 47 of Set 27 | sal rei
# Processing Record 48 of Set 27 | sisimiut
# Processing Record 49 of Set 27 | muzhi
# Processing Record 50 of Set 27 | pa sang
# Processing Record 1 of Set 28 | belmonte
# Processing Record 2 of Set 28 | caravelas
# Processing Record 3 of Set 28 | tosham
# Processing Record 4 of Set 28 | santiago
# Processing Record 5 of Set 28 | narasannapeta
# Processing Record 6 of Set 28 | amapa
# Processing Record 7 of Set 28 | kiama
# Processing Record 8 of Set 28 | anuppur
# Processing Record 9 of Set 28 | ellensburg
# Processing Record 10 of Set 28 | luganville
# Processing Record 11 of Set 28 | alofi
# Processing Record 12 of Set 28 | mukono
# Processing Record 13 of Set 28 | baraboo
# Processing Record 14 of Set 28 | taseyevo
# Processing Record 15 of Set 28 | nikki
# Processing Record 16 of Set 28 | boden
# Processing Record 17 of Set 28 | tatarbunary
# Processing Record 18 of Set 28 | santa maria
# Processing Record 19 of Set 28 | songjianghe
# Processing Record 20 of Set 28 | vilyuysk
# Processing Record 21 of Set 28 | santana do livramento
# Processing Record 22 of Set 28 | tadine
# Processing Record 23 of Set 28 | kushima
# Processing Record 24 of Set 28 | banjar
# Processing Record 25 of Set 28 | ginda
# Processing Record 26 of Set 28 | labuhan
# Processing Record 27 of Set 28 | paragominas
# Processing Record 28 of Set 28 | havoysund
# Processing Record 29 of Set 28 | melton
# Processing Record 30 of Set 28 | waingapu
# Processing Record 31 of Set 28 | svetlyy
# Processing Record 32 of Set 28 | sarangani
# Processing Record 33 of Set 28 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 28 | hawera
# Processing Record 35 of Set 28 | vrable
# Processing Record 36 of Set 28 | igdir
# Processing Record 37 of Set 28 | wewak
# Processing Record 38 of Set 28 | voi
# Processing Record 39 of Set 28 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 28 | fort walton beach
# Processing Record 41 of Set 28 | karratha
# Processing Record 42 of Set 28 | ust-kishert
# Processing Record 43 of Set 28 | tomohon
# Processing Record 44 of Set 28 | mandera
# Processing Record 45 of Set 28 | port macquarie
# Processing Record 46 of Set 28 | dakar
# Processing Record 47 of Set 28 | te anau
# Processing Record 48 of Set 28 | adamas
# Processing Record 49 of Set 28 | campos novos
# Processing Record 50 of Set 28 | beloha
# Processing Record 1 of Set 29 | tarko-sale
# Processing Record 2 of Set 29 | andevoranto
# City not found. Skipping...
# Processing Record 3 of Set 29 | vostok
# Processing Record 4 of Set 29 | san julian
# Processing Record 5 of Set 29 | narsaq
# Processing Record 6 of Set 29 | toktogul
# Processing Record 7 of Set 29 | mahadday weyne
# City not found. Skipping...
# Processing Record 8 of Set 29 | dingle
# Processing Record 9 of Set 29 | gat
# Processing Record 10 of Set 29 | guozhen
# Processing Record 11 of Set 29 | lahaina
# Processing Record 12 of Set 29 | channel-port aux basques
# Processing Record 13 of Set 29 | nantucket
# Processing Record 14 of Set 29 | yurga
# Processing Record 15 of Set 29 | zaysan
# Processing Record 16 of Set 29 | khilok
# Processing Record 17 of Set 29 | half moon bay
# Processing Record 18 of Set 29 | saint anthony
# Processing Record 19 of Set 29 | gravdal
# Processing Record 20 of Set 29 | pokosnoye
# Processing Record 21 of Set 29 | barzas
# Processing Record 22 of Set 29 | seoul
# Processing Record 23 of Set 29 | brae
# Processing Record 24 of Set 29 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 29 | falavarjan
# Processing Record 26 of Set 29 | soligalich
# Processing Record 27 of Set 29 | kaeo
# Processing Record 28 of Set 29 | kargil
# Processing Record 29 of Set 29 | kindu
# Processing Record 30 of Set 29 | ahipara
# Processing Record 31 of Set 29 | greve strand
# Processing Record 32 of Set 29 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 29 | codrington
# Processing Record 34 of Set 29 | mackay
# Processing Record 35 of Set 29 | bonfim
# Processing Record 36 of Set 29 | bardiyah
# Processing Record 37 of Set 29 | kuah
# Processing Record 38 of Set 29 | mgachi
# Processing Record 39 of Set 29 | zhigansk
# Processing Record 40 of Set 29 | xambioa
# Processing Record 41 of Set 29 | takestan
# Processing Record 42 of Set 29 | nioro
# Processing Record 43 of Set 29 | itabaianinha
# Processing Record 44 of Set 29 | batticaloa
# Processing Record 45 of Set 29 | granger
# Processing Record 46 of Set 29 | xiangfan
# Processing Record 47 of Set 29 | qasigiannguit
# Processing Record 48 of Set 29 | awbari
# Processing Record 49 of Set 29 | mabaruma
# Processing Record 50 of Set 29 | monrovia
# Processing Record 1 of Set 30 | ormara
# Processing Record 2 of Set 30 | ahuimanu
# Processing Record 3 of Set 30 | krasnovishersk
# Processing Record 4 of Set 30 | hachinohe
# Processing Record 5 of Set 30 | mairi
# Processing Record 6 of Set 30 | alice springs
# Processing Record 7 of Set 30 | nayoro
# Processing Record 8 of Set 30 | mattru
# Processing Record 9 of Set 30 | general pico
# Processing Record 10 of Set 30 | jabiru
# City not found. Skipping...
# Processing Record 11 of Set 30 | luba
# Processing Record 12 of Set 30 | birkenfeld
# Processing Record 13 of Set 30 | magistralnyy
# Processing Record 14 of Set 30 | kondinskoye
# Processing Record 15 of Set 30 | tilichiki
# Processing Record 16 of Set 30 | saint-georges
# Processing Record 17 of Set 30 | ushtobe
# Processing Record 18 of Set 30 | esna
# Processing Record 19 of Set 30 | bubaque
# Processing Record 20 of Set 30 | sorong
# Processing Record 21 of Set 30 | leh
# Processing Record 22 of Set 30 | shar
# Processing Record 23 of Set 30 | nyurba
# Processing Record 24 of Set 30 | watford
# Processing Record 25 of Set 30 | ipixuna
# Processing Record 26 of Set 30 | sai buri
# Processing Record 27 of Set 30 | coquimbo
# Processing Record 28 of Set 30 | umm jarr
# City not found. Skipping...
# Processing Record 29 of Set 30 | creel
# Processing Record 30 of Set 30 | jahrom
# City not found. Skipping...
# Processing Record 31 of Set 30 | shevchenkove
# Processing Record 32 of Set 30 | acajutla
# Processing Record 33 of Set 30 | makakilo city
# Processing Record 34 of Set 30 | cananeia
# Processing Record 35 of Set 30 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 30 | luanda
# Processing Record 37 of Set 30 | lakselv
# Processing Record 38 of Set 30 | saint-augustin
# Processing Record 39 of Set 30 | chimbote
# Processing Record 40 of Set 30 | diu
# Processing Record 41 of Set 30 | karmana
# City not found. Skipping...
# Processing Record 42 of Set 30 | davila
# Processing Record 43 of Set 30 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 30 | marawi
# Processing Record 45 of Set 30 | orthez
# Processing Record 46 of Set 30 | saint-alexandre
# Processing Record 47 of Set 30 | wagga wagga
# Processing Record 48 of Set 30 | marfino
# Processing Record 49 of Set 30 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 30 | muana
# Processing Record 1 of Set 31 | aberdeen
# Processing Record 2 of Set 31 | rapid city
# Processing Record 3 of Set 31 | balkanabat
# Processing Record 4 of Set 31 | tromso
# Processing Record 5 of Set 31 | mikuni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Soyo  -6.1349   12.3689     78.71        89          97
# 1     Butaritari   3.0707  172.7902     82.11        76          25
# 2       Thompson  55.7435  -97.8558     -0.24        71          40
# 3        Kavieng  -2.5744  150.7967     82.18        75         100
# 4      Ilulissat  69.2167  -51.1000     12.22        57          75
# 5       Klaksvik  62.2266   -6.5890     34.72        63          60
# 6  Ponta Delgada  37.7333  -25.6667     59.50        77          20
# 7           Lamu  -2.2717   40.9020     79.02        84           3
# 8         Atuona  -9.8000 -139.0333     77.72        75          18
# 9       Berlevag  70.8578   29.0864     19.40        79          98
#
#    Wind Speed Country Current Description
# 0        4.74      AO          light rain
# 1       19.89      KI          light rain
# 2        5.75      CA    scattered clouds
# 3        7.36      PG          light rain
# 4       19.57      GL       broken clouds
# 5       28.54      FO       broken clouds
# 6        8.05      PT          few clouds
# 7       11.54      KE           clear sky
# 8       13.67      PF          few clouds
# 9        5.84      NO     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Soyo      AO  -6.1349   12.3689     78.71        89          97
# 1    Butaritari      KI   3.0707  172.7902     82.11        76          25
# 2      Thompson      CA  55.7435  -97.8558     -0.24        71          40
# 3       Kavieng      PG  -2.5744  150.7967     82.18        75         100
# 4     Ilulissat      GL  69.2167  -51.1000     12.22        57          75
# ..          ...     ...      ...       ...       ...       ...         ...
# 689    Aberdeen      GB  57.1437   -2.0981     41.49        68          20
# 690  Rapid City      US  44.0805 -103.2310     56.50        15           0
# 691  Balkanabat      TM  39.5108   54.3671     41.50        61           6
# 692      Tromso      NO  69.6496   18.9570     21.22        58           0
# 693      Mikuni      JP  36.2171  136.1519     35.51        82          95
#
#      Wind Speed Current Description
# 0          4.74          light rain
# 1         19.89          light rain
# 2          5.75    scattered clouds
# 3          7.36          light rain
# 4         19.57       broken clouds
# ..          ...                 ...
# 689       19.57          few clouds
# 690        8.99           clear sky
# 691        5.06           clear sky
# 692        4.61           clear sky
# 693       18.12     overcast clouds
#
# [694 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
