# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # current description of weather for city.
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | yellowknife
# Processing Record 2 of Set 13 | lompoc
# Processing Record 3 of Set 13 | opuwo
# Processing Record 4 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 13 | albany
# Processing Record 6 of Set 13 | ginir
# Processing Record 7 of Set 13 | rikitea
# Processing Record 8 of Set 13 | ahar
# Processing Record 9 of Set 13 | airai
# Processing Record 10 of Set 13 | bethel
# Processing Record 11 of Set 13 | ejura
# Processing Record 12 of Set 13 | hervey bay
# Processing Record 13 of Set 13 | ushuaia
# Processing Record 14 of Set 13 | hermanus
# Processing Record 15 of Set 13 | cocal
# Processing Record 16 of Set 13 | buraydah
# Processing Record 17 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 13 | qaanaaq
# Processing Record 19 of Set 13 | mataura
# Processing Record 20 of Set 13 | iquitos
# Processing Record 21 of Set 13 | bonfim
# Processing Record 22 of Set 13 | olafsvik
# Processing Record 23 of Set 13 | puerto ayora
# Processing Record 24 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 13 | dikson
# Processing Record 26 of Set 13 | vaini
# Processing Record 27 of Set 13 | busselton
# Processing Record 28 of Set 13 | chuy
# Processing Record 29 of Set 13 | barrow
# Processing Record 30 of Set 13 | hithadhoo
# Processing Record 31 of Set 13 | zavodskoy
# Processing Record 32 of Set 13 | shumyachi
# Processing Record 33 of Set 13 | san policarpo
# Processing Record 34 of Set 13 | salalah
# Processing Record 35 of Set 13 | jamestown
# Processing Record 36 of Set 13 | atuona
# Processing Record 37 of Set 13 | bikin
# Processing Record 38 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 13 | bluff
# Processing Record 41 of Set 13 | coihueco
# Processing Record 42 of Set 13 | butaritari
# Processing Record 43 of Set 13 | new norfolk
# Processing Record 44 of Set 13 | vestmannaeyjar
# Processing Record 45 of Set 13 | nefteyugansk
# Processing Record 46 of Set 13 | san patricio
# Processing Record 47 of Set 13 | saint george
# Processing Record 48 of Set 13 | kidal
# Processing Record 49 of Set 13 | filadelfia
# Processing Record 50 of Set 13 | khartoum
# Processing Record 1 of Set 14 | olga
# Processing Record 2 of Set 14 | hobart
# Processing Record 3 of Set 14 | aklavik
# Processing Record 4 of Set 14 | berlin
# Processing Record 5 of Set 14 | lebu
# Processing Record 6 of Set 14 | tarakan
# Processing Record 7 of Set 14 | bose
# Processing Record 8 of Set 14 | tasiilaq
# Processing Record 9 of Set 14 | khatanga
# Processing Record 10 of Set 14 | nioro
# Processing Record 11 of Set 14 | arraial do cabo
# Processing Record 12 of Set 14 | skjervoy
# Processing Record 13 of Set 14 | batagay-alyta
# Processing Record 14 of Set 14 | constitucion
# Processing Record 15 of Set 14 | apiai
# Processing Record 16 of Set 14 | avarua
# Processing Record 17 of Set 14 | xai-xai
# Processing Record 18 of Set 14 | carballo
# Processing Record 19 of Set 14 | dutse
# Processing Record 20 of Set 14 | esperance
# Processing Record 21 of Set 14 | saint-louis
# Processing Record 22 of Set 14 | port alfred
# Processing Record 23 of Set 14 | iqaluit
# Processing Record 24 of Set 14 | wilmington
# Processing Record 25 of Set 14 | port lincoln
# Processing Record 26 of Set 14 | presidencia roque saenz pena
# Processing Record 27 of Set 14 | kyshtovka
# Processing Record 28 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 14 | benguela
# Processing Record 30 of Set 14 | sidi qasim
# City not found. Skipping...
# Processing Record 31 of Set 14 | punta arenas
# Processing Record 32 of Set 14 | comodoro rivadavia
# Processing Record 33 of Set 14 | penzance
# Processing Record 34 of Set 14 | awbari
# Processing Record 35 of Set 14 | clyde river
# Processing Record 36 of Set 14 | bolobo
# Processing Record 37 of Set 14 | nanyang
# Processing Record 38 of Set 14 | thompson
# Processing Record 39 of Set 14 | alofi
# Processing Record 40 of Set 14 | kodiak
# Processing Record 41 of Set 14 | carahue
# Processing Record 42 of Set 14 | mazyr
# Processing Record 43 of Set 14 | kapaa
# Processing Record 44 of Set 14 | pevek
# Processing Record 45 of Set 14 | udachnyy
# Processing Record 46 of Set 14 | la ronge
# Processing Record 47 of Set 14 | songjianghe
# Processing Record 48 of Set 14 | maniitsoq
# Processing Record 49 of Set 14 | ponta do sol
# Processing Record 50 of Set 14 | guane
# Processing Record 1 of Set 15 | omboue
# Processing Record 2 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 15 | sjenica
# Processing Record 4 of Set 15 | troitsko-pechorsk
# Processing Record 5 of Set 15 | port said
# Processing Record 6 of Set 15 | coihaique
# Processing Record 7 of Set 15 | sapouy
# Processing Record 8 of Set 15 | hualmay
# Processing Record 9 of Set 15 | vila franca do campo
# Processing Record 10 of Set 15 | pisco
# Processing Record 11 of Set 15 | pavlivka
# Processing Record 12 of Set 15 | sao joao da barra
# Processing Record 13 of Set 15 | piazza armerina
# Processing Record 14 of Set 15 | saldanha
# Processing Record 15 of Set 15 | grindavik
# Processing Record 16 of Set 15 | berlevag
# Processing Record 17 of Set 15 | ugoofaaru
# Processing Record 18 of Set 15 | zabaykalsk
# Processing Record 19 of Set 15 | hilo
# Processing Record 20 of Set 15 | east london
# Processing Record 21 of Set 15 | bathsheba
# Processing Record 22 of Set 15 | lata
# Processing Record 23 of Set 15 | balaipungut
# Processing Record 24 of Set 15 | port elizabeth
# Processing Record 25 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 26 of Set 15 | severo-kurilsk
# Processing Record 27 of Set 15 | sosva
# Processing Record 28 of Set 15 | verkhnyaya inta
# Processing Record 29 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 15 | ariquemes
# Processing Record 31 of Set 15 | beringovskiy
# Processing Record 32 of Set 15 | el fuerte
# Processing Record 33 of Set 15 | ribeira grande
# Processing Record 34 of Set 15 | corrente
# Processing Record 35 of Set 15 | bilibino
# Processing Record 36 of Set 15 | soyo
# Processing Record 37 of Set 15 | ilulissat
# Processing Record 38 of Set 15 | lexington-fayette
# Processing Record 39 of Set 15 | tupik
# Processing Record 40 of Set 15 | sao sebastiao
# Processing Record 41 of Set 15 | sao filipe
# Processing Record 42 of Set 15 | bow island
# Processing Record 43 of Set 15 | caravelas
# Processing Record 44 of Set 15 | evensk
# Processing Record 45 of Set 15 | murray bridge
# Processing Record 46 of Set 15 | norman wells
# Processing Record 47 of Set 15 | zharkent
# Processing Record 48 of Set 15 | mar del plata
# Processing Record 49 of Set 15 | moissala
# Processing Record 50 of Set 15 | mahebourg
# Processing Record 1 of Set 16 | trincomalee
# Processing Record 2 of Set 16 | flinders
# Processing Record 3 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 16 | luanda
# Processing Record 5 of Set 16 | gibsons
# Processing Record 6 of Set 16 | tandil
# Processing Record 7 of Set 16 | nagua
# Processing Record 8 of Set 16 | hay river
# Processing Record 9 of Set 16 | maceio
# Processing Record 10 of Set 16 | tekkali
# Processing Record 11 of Set 16 | bredasdorp
# Processing Record 12 of Set 16 | antalaha
# Processing Record 13 of Set 16 | konakovo
# Processing Record 14 of Set 16 | honningsvag
# Processing Record 15 of Set 16 | waipawa
# Processing Record 16 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 16 | kanigiri
# Processing Record 18 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 16 | gamba
# Processing Record 21 of Set 16 | gaspar
# Processing Record 22 of Set 16 | trinidad
# Processing Record 23 of Set 16 | pokhara
# Processing Record 24 of Set 16 | benghazi
# Processing Record 25 of Set 16 | kahului
# Processing Record 26 of Set 16 | exeter
# Processing Record 27 of Set 16 | muisne
# Processing Record 28 of Set 16 | saint-philippe
# Processing Record 29 of Set 16 | castro
# Processing Record 30 of Set 16 | faanui
# Processing Record 31 of Set 16 | narsaq
# Processing Record 32 of Set 16 | port hardy
# Processing Record 33 of Set 16 | lazaro cardenas
# Processing Record 34 of Set 16 | roebourne
# Processing Record 35 of Set 16 | ambilobe
# Processing Record 36 of Set 16 | san quintin
# Processing Record 37 of Set 16 | nshamba
# Processing Record 38 of Set 16 | mount gambier
# Processing Record 39 of Set 16 | neuquen
# Processing Record 40 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 16 | cherskiy
# Processing Record 42 of Set 16 | puerto del rosario
# Processing Record 43 of Set 16 | carnarvon
# Processing Record 44 of Set 16 | alice springs
# Processing Record 45 of Set 16 | kupang
# Processing Record 46 of Set 16 | norsup
# Processing Record 47 of Set 16 | ola
# Processing Record 48 of Set 16 | tuktoyaktuk
# Processing Record 49 of Set 16 | kavieng
# Processing Record 50 of Set 16 | cape town
# Processing Record 1 of Set 17 | jos
# Processing Record 2 of Set 17 | itajuipe
# Processing Record 3 of Set 17 | georgetown
# Processing Record 4 of Set 17 | tuatapere
# Processing Record 5 of Set 17 | puerto escondido
# Processing Record 6 of Set 17 | korsakov
# Processing Record 7 of Set 17 | emba
# Processing Record 8 of Set 17 | nabire
# Processing Record 9 of Set 17 | dhangadhi
# Processing Record 10 of Set 17 | riyadh
# Processing Record 11 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 17 | tiksi
# Processing Record 13 of Set 17 | novolvovsk
# City not found. Skipping...
# Processing Record 14 of Set 17 | kirkwood
# Processing Record 15 of Set 17 | burnie
# Processing Record 16 of Set 17 | rio gallegos
# Processing Record 17 of Set 17 | manggar
# Processing Record 18 of Set 17 | caernarfon
# Processing Record 19 of Set 17 | singaparna
# Processing Record 20 of Set 17 | vila velha
# Processing Record 21 of Set 17 | san cristobal
# Processing Record 22 of Set 17 | goderich
# Processing Record 23 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 17 | mayo
# Processing Record 25 of Set 17 | agadez
# Processing Record 26 of Set 17 | murgab
# Processing Record 27 of Set 17 | vasteras
# Processing Record 28 of Set 17 | kopavogur
# Processing Record 29 of Set 17 | port hedland
# Processing Record 30 of Set 17 | talnakh
# Processing Record 31 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 17 | sabang
# Processing Record 33 of Set 17 | dixon
# Processing Record 34 of Set 17 | coahuayana
# Processing Record 35 of Set 17 | nikolskoye
# Processing Record 36 of Set 17 | dombarovskiy
# Processing Record 37 of Set 17 | akhtanizovskaya
# Processing Record 38 of Set 17 | kenai
# Processing Record 39 of Set 17 | kailua
# Processing Record 40 of Set 17 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 17 | odienne
# Processing Record 42 of Set 17 | felanitx
# Processing Record 43 of Set 17 | upernavik
# Processing Record 44 of Set 17 | baruun-urt
# Processing Record 45 of Set 17 | ippy
# Processing Record 46 of Set 17 | egvekinot
# Processing Record 47 of Set 17 | saskylakh
# Processing Record 48 of Set 17 | victoria
# Processing Record 49 of Set 17 | lorengau
# Processing Record 50 of Set 17 | luderitz
# Processing Record 1 of Set 18 | buala
# Processing Record 2 of Set 18 | mankachar
# Processing Record 3 of Set 18 | aksarka
# Processing Record 4 of Set 18 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 18 | qaqortoq
# Processing Record 6 of Set 18 | yaqui
# Processing Record 7 of Set 18 | kloulklubed
# Processing Record 8 of Set 18 | salinopolis
# Processing Record 9 of Set 18 | warrington
# Processing Record 10 of Set 18 | praya
# Processing Record 11 of Set 18 | margate
# Processing Record 12 of Set 18 | ancud
# Processing Record 13 of Set 18 | leningradskiy
# Processing Record 14 of Set 18 | karaman
# Processing Record 15 of Set 18 | saint anthony
# Processing Record 16 of Set 18 | lagoa da prata
# Processing Record 17 of Set 18 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 18 | prince rupert
# Processing Record 19 of Set 18 | umm ruwabah
# City not found. Skipping...
# Processing Record 20 of Set 18 | cabo san lucas
# Processing Record 21 of Set 18 | coquimbo
# Processing Record 22 of Set 18 | los llanos de aridane
# Processing Record 23 of Set 18 | ciras
# City not found. Skipping...
# Processing Record 24 of Set 18 | swan river
# Processing Record 25 of Set 18 | shimoda
# Processing Record 26 of Set 18 | bengkulu
# Processing Record 27 of Set 18 | chokurdakh
# Processing Record 28 of Set 18 | fortuna
# Processing Record 29 of Set 18 | la roda
# Processing Record 30 of Set 18 | half moon bay
# Processing Record 31 of Set 18 | yeppoon
# Processing Record 32 of Set 18 | cairns
# Processing Record 33 of Set 18 | pierre
# Processing Record 34 of Set 18 | merauke
# Processing Record 35 of Set 18 | komsomolskiy
# Processing Record 36 of Set 18 | bela vista
# Processing Record 37 of Set 18 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 18 | orotukan
# Processing Record 39 of Set 18 | abashiri
# Processing Record 40 of Set 18 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 18 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 18 | bundaberg
# Processing Record 43 of Set 18 | zeya
# Processing Record 44 of Set 18 | rio grande
# Processing Record 45 of Set 18 | yerbogachen
# Processing Record 46 of Set 18 | sitka
# Processing Record 47 of Set 18 | vaitape
# Processing Record 48 of Set 18 | cidreira
# Processing Record 49 of Set 18 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 50 of Set 18 | bubaque
# Processing Record 1 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 19 | camacupa
# Processing Record 3 of Set 19 | kununurra
# Processing Record 4 of Set 19 | kirakira
# Processing Record 5 of Set 19 | karamay
# City not found. Skipping...
# Processing Record 6 of Set 19 | sadao
# Processing Record 7 of Set 19 | ostrovnoy
# Processing Record 8 of Set 19 | poltsamaa
# Processing Record 9 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 19 | kalcheva
# Processing Record 12 of Set 19 | marawi
# Processing Record 13 of Set 19 | rongcheng
# Processing Record 14 of Set 19 | bulgan
# Processing Record 15 of Set 19 | kaitangata
# Processing Record 16 of Set 19 | hastings
# Processing Record 17 of Set 19 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 18 of Set 19 | gizo
# Processing Record 19 of Set 19 | port macquarie
# Processing Record 20 of Set 19 | moose factory
# Processing Record 21 of Set 19 | dunedin
# Processing Record 22 of Set 19 | porto novo
# Processing Record 23 of Set 19 | vreed en hoop
# City not found. Skipping...
# Processing Record 24 of Set 19 | bambous virieux
# Processing Record 25 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 19 | kochubey
# Processing Record 27 of Set 19 | new waterford
# Processing Record 28 of Set 19 | broome
# Processing Record 29 of Set 19 | shingu
# Processing Record 30 of Set 19 | bandarbeyla
# Processing Record 31 of Set 19 | soc trang
# Processing Record 32 of Set 19 | kaeo
# Processing Record 33 of Set 19 | souillac
# Processing Record 34 of Set 19 | pacific grove
# Processing Record 35 of Set 19 | westport
# Processing Record 36 of Set 19 | rostovka
# Processing Record 37 of Set 19 | khromtau
# Processing Record 38 of Set 19 | ondjiva
# Processing Record 39 of Set 19 | medianeira
# Processing Record 40 of Set 19 | behbahan
# Processing Record 41 of Set 19 | arona
# Processing Record 42 of Set 19 | fairbanks
# Processing Record 43 of Set 19 | newport
# Processing Record 44 of Set 19 | logan
# Processing Record 45 of Set 19 | wanning
# Processing Record 46 of Set 19 | jinji
# Processing Record 47 of Set 19 | ewa beach
# Processing Record 48 of Set 19 | gat
# Processing Record 49 of Set 19 | gushikawa
# Processing Record 50 of Set 19 | penticton
# Processing Record 1 of Set 20 | taltal
# Processing Record 2 of Set 20 | grobina
# Processing Record 3 of Set 20 | halifax
# Processing Record 4 of Set 20 | saint-pierre
# Processing Record 5 of Set 20 | port hawkesbury
# Processing Record 6 of Set 20 | luba
# Processing Record 7 of Set 20 | tignere
# Processing Record 8 of Set 20 | katobu
# Processing Record 9 of Set 20 | aguimes
# Processing Record 10 of Set 20 | mbengwi
# Processing Record 11 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 20 | santa isabel do rio negro
# Processing Record 13 of Set 20 | longyearbyen
# Processing Record 14 of Set 20 | yumen
# Processing Record 15 of Set 20 | gagino
# Processing Record 16 of Set 20 | nalut
# Processing Record 17 of Set 20 | poum
# Processing Record 18 of Set 20 | uberlingen
# Processing Record 19 of Set 20 | nelson bay
# Processing Record 20 of Set 20 | macapa
# Processing Record 21 of Set 20 | thiruvananthapuram
# Processing Record 22 of Set 20 | moroni
# Processing Record 23 of Set 20 | puli
# Processing Record 24 of Set 20 | carmen
# Processing Record 25 of Set 20 | darovskoy
# Processing Record 26 of Set 20 | najran
# Processing Record 27 of Set 20 | morant bay
# Processing Record 28 of Set 20 | tautira
# Processing Record 29 of Set 20 | marsh harbour
# Processing Record 30 of Set 20 | brae
# Processing Record 31 of Set 20 | hamilton
# Processing Record 32 of Set 20 | amanganj
# Processing Record 33 of Set 20 | great falls
# Processing Record 34 of Set 20 | amuntai
# Processing Record 35 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 20 | san juan
# Processing Record 37 of Set 20 | grand forks
# Processing Record 38 of Set 20 | isla vista
# Processing Record 39 of Set 20 | borogontsy
# Processing Record 40 of Set 20 | bud
# Processing Record 41 of Set 20 | blagoveshchenka
# Processing Record 42 of Set 20 | hasaki
# Processing Record 43 of Set 20 | tomatlan
# Processing Record 44 of Set 20 | rinteln
# Processing Record 45 of Set 20 | billings
# Processing Record 46 of Set 20 | padang
# Processing Record 47 of Set 20 | mehamn
# Processing Record 48 of Set 20 | geraldton
# Processing Record 49 of Set 20 | vardo
# Processing Record 50 of Set 20 | aksu
# Processing Record 1 of Set 21 | linhares
# Processing Record 2 of Set 21 | grand gaube
# Processing Record 3 of Set 21 | middelburg
# Processing Record 4 of Set 21 | richards bay
# Processing Record 5 of Set 21 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 21 | santo domingo
# Processing Record 7 of Set 21 | pangnirtung
# Processing Record 8 of Set 21 | anadyr
# Processing Record 9 of Set 21 | aginskoye
# Processing Record 10 of Set 21 | general roca
# Processing Record 11 of Set 21 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 21 | starotimoshkino
# Processing Record 13 of Set 21 | voh
# Processing Record 14 of Set 21 | selam
# Processing Record 15 of Set 21 | kichmengskiy gorodok
# Processing Record 16 of Set 21 | derzhavinsk
# Processing Record 17 of Set 21 | serik
# Processing Record 18 of Set 21 | lavrentiya
# Processing Record 19 of Set 21 | ambovombe
# Processing Record 20 of Set 21 | azare
# Processing Record 21 of Set 21 | melo
# Processing Record 22 of Set 21 | ingham
# Processing Record 23 of Set 21 | mastic beach
# Processing Record 24 of Set 21 | oranzherei
# Processing Record 25 of Set 21 | ifanadiana
# Processing Record 26 of Set 21 | katsuura
# Processing Record 27 of Set 21 | seymchan
# Processing Record 28 of Set 21 | southbridge
# Processing Record 29 of Set 21 | asau
# Processing Record 30 of Set 21 | gandu
# Processing Record 31 of Set 21 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 21 | koindu
# Processing Record 33 of Set 21 | sawtell
# Processing Record 34 of Set 21 | puerto colombia
# Processing Record 35 of Set 21 | palembang
# Processing Record 36 of Set 21 | harper
# Processing Record 37 of Set 21 | namatanai
# Processing Record 38 of Set 21 | klaksvik
# Processing Record 39 of Set 21 | puerto narino
# Processing Record 40 of Set 21 | nangan
# Processing Record 41 of Set 21 | amapa
# Processing Record 42 of Set 21 | canete
# Processing Record 43 of Set 21 | cayenne
# Processing Record 44 of Set 21 | broken hill
# Processing Record 45 of Set 21 | dandong
# Processing Record 46 of Set 21 | nome
# Processing Record 47 of Set 21 | sanghar
# Processing Record 48 of Set 21 | oranjemund
# Processing Record 49 of Set 21 | cheuskiny
# City not found. Skipping...
# Processing Record 50 of Set 21 | mayumba
# Processing Record 1 of Set 22 | valdivia
# Processing Record 2 of Set 22 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 22 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 22 | esso
# Processing Record 5 of Set 22 | turochak
# Processing Record 6 of Set 22 | winnemucca
# Processing Record 7 of Set 22 | cap malheureux
# Processing Record 8 of Set 22 | bonavista
# Processing Record 9 of Set 22 | nanortalik
# Processing Record 10 of Set 22 | haileybury
# Processing Record 11 of Set 22 | srednekolymsk
# Processing Record 12 of Set 22 | vao
# Processing Record 13 of Set 22 | cedar city
# Processing Record 14 of Set 22 | inhambane
# Processing Record 15 of Set 22 | karratha
# Processing Record 16 of Set 22 | svetlaya
# Processing Record 17 of Set 22 | sutysky
# Processing Record 18 of Set 22 | punto fijo
# Processing Record 19 of Set 22 | beloha
# Processing Record 20 of Set 22 | acari
# Processing Record 21 of Set 22 | svetlogorsk
# Processing Record 22 of Set 22 | russell
# Processing Record 23 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 22 | port moresby
# Processing Record 25 of Set 22 | inuvik
# Processing Record 26 of Set 22 | yangambi
# Processing Record 27 of Set 22 | george
# Processing Record 28 of Set 22 | lagoa
# Processing Record 29 of Set 22 | garner
# Processing Record 30 of Set 22 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 22 | sakakah
# Processing Record 32 of Set 22 | huangmei
# Processing Record 33 of Set 22 | chimbote
# Processing Record 34 of Set 22 | jibuti
# Processing Record 35 of Set 22 | atambua
# Processing Record 36 of Set 22 | kawalu
# Processing Record 37 of Set 22 | bol
# Processing Record 38 of Set 22 | guadalupe victoria
# Processing Record 39 of Set 22 | hofn
# Processing Record 40 of Set 22 | yarada
# Processing Record 41 of Set 22 | duz
# City not found. Skipping...
# Processing Record 42 of Set 22 | copiapo
# Processing Record 43 of Set 22 | uhlove
# Processing Record 44 of Set 22 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 22 | palmer
# Processing Record 46 of Set 22 | skibotn
# Processing Record 47 of Set 22 | anito
# Processing Record 48 of Set 22 | iquique
# Processing Record 49 of Set 22 | ruidoso
# Processing Record 50 of Set 22 | namibe
# Processing Record 1 of Set 23 | bambey
# Processing Record 2 of Set 23 | abha
# Processing Record 3 of Set 23 | sayyan
# Processing Record 4 of Set 23 | la sarre
# Processing Record 5 of Set 23 | plouzane
# Processing Record 6 of Set 23 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 23 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 23 | zhigansk
# Processing Record 9 of Set 23 | nishihara
# Processing Record 10 of Set 23 | malanje
# Processing Record 11 of Set 23 | nueva loja
# Processing Record 12 of Set 23 | dingle
# Processing Record 13 of Set 23 | petropavlovka
# Processing Record 14 of Set 23 | tocopilla
# Processing Record 15 of Set 23 | bogorodskoye
# Processing Record 16 of Set 23 | fukue
# Processing Record 17 of Set 23 | rondonopolis
# Processing Record 18 of Set 23 | rapid valley
# Processing Record 19 of Set 23 | novobirilyussy
# Processing Record 20 of Set 23 | votkinsk
# Processing Record 21 of Set 23 | isiro
# Processing Record 22 of Set 23 | salvador
# Processing Record 23 of Set 23 | okakarara
# Processing Record 24 of Set 23 | prince albert
# Processing Record 25 of Set 23 | petropavl
# Processing Record 26 of Set 23 | alakurtti
# Processing Record 27 of Set 23 | kalmunai
# Processing Record 28 of Set 23 | novyy urengoy
# Processing Record 29 of Set 23 | lae
# Processing Record 30 of Set 23 | moron
# Processing Record 31 of Set 23 | dunkirk
# Processing Record 32 of Set 23 | manono
# Processing Record 33 of Set 23 | fort nelson
# Processing Record 34 of Set 23 | axim
# Processing Record 35 of Set 23 | mahibadhoo
# Processing Record 36 of Set 23 | praia da vitoria
# Processing Record 37 of Set 23 | muravlenko
# Processing Record 38 of Set 23 | whitianga
# Processing Record 39 of Set 23 | port blair
# Processing Record 40 of Set 23 | lyubeshiv
# City not found. Skipping...
# Processing Record 41 of Set 23 | charters towers
# Processing Record 42 of Set 23 | panzhihua
# Processing Record 43 of Set 23 | moindou
# Processing Record 44 of Set 23 | college
# Processing Record 45 of Set 23 | roma
# Processing Record 46 of Set 23 | maksatikha
# Processing Record 47 of Set 23 | ekhabi
# Processing Record 48 of Set 23 | arandis
# Processing Record 49 of Set 23 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 23 | tombouctou
# Processing Record 1 of Set 24 | huautla
# Processing Record 2 of Set 24 | kruisfontein
# Processing Record 3 of Set 24 | korla
# Processing Record 4 of Set 24 | nkoteng
# Processing Record 5 of Set 24 | zhigalovo
# Processing Record 6 of Set 24 | bang krathum
# Processing Record 7 of Set 24 | tecoanapa
# Processing Record 8 of Set 24 | bertoua
# Processing Record 9 of Set 24 | deputatskiy
# Processing Record 10 of Set 24 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 24 | eregli
# Processing Record 12 of Set 24 | novoilinsk
# Processing Record 13 of Set 24 | grootfontein
# Processing Record 14 of Set 24 | okhotsk
# Processing Record 15 of Set 24 | aranos
# Processing Record 16 of Set 24 | mayya
# Processing Record 17 of Set 24 | xifeng
# Processing Record 18 of Set 24 | antofagasta
# Processing Record 19 of Set 24 | santa marinella
# Processing Record 20 of Set 24 | rocha
# Processing Record 21 of Set 24 | kemptville
# Processing Record 22 of Set 24 | sao felix do xingu
# Processing Record 23 of Set 24 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 24 | lodwar
# Processing Record 25 of Set 24 | chingirlau
# Processing Record 26 of Set 24 | lerwick
# Processing Record 27 of Set 24 | guelengdeng
# City not found. Skipping...
# Processing Record 28 of Set 24 | raudeberg
# Processing Record 29 of Set 24 | vikulovo
# Processing Record 30 of Set 24 | inverness
# Processing Record 31 of Set 24 | ahipara
# Processing Record 32 of Set 24 | naze
# Processing Record 33 of Set 24 | maralal
# Processing Record 34 of Set 24 | mikhaylov
# Processing Record 35 of Set 24 | huarmey
# Processing Record 36 of Set 24 | birjand
# Processing Record 37 of Set 24 | parabel
# Processing Record 38 of Set 24 | balkhash
# Processing Record 39 of Set 24 | armacao dos buzios
# City not found. Skipping...
# Processing Record 40 of Set 24 | zambezi
# Processing Record 41 of Set 24 | buritizeiro
# Processing Record 42 of Set 24 | caluquembe
# Processing Record 43 of Set 24 | saint-augustin
# Processing Record 44 of Set 24 | baltay
# Processing Record 45 of Set 24 | fez
# Processing Record 46 of Set 24 | polson
# Processing Record 47 of Set 24 | muros
# Processing Record 48 of Set 24 | avera
# Processing Record 49 of Set 24 | kulhudhuffushi
# Processing Record 50 of Set 24 | launceston
# Processing Record 1 of Set 25 | touros
# Processing Record 2 of Set 25 | tura
# Processing Record 3 of Set 25 | qasigiannguit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Yellowknife  62.4560 -114.3525     -4.59        85         100        5.75
# 1       Lompoc  34.6391 -120.4579     68.09        43           0        5.75
# 2        Opuwo -18.0607   13.8400     73.80        36         100       13.04
# 3       Albany  42.6001  -73.9662     14.81        64         100       10.00
# 4        Ginir   7.1333   40.7000     61.09        16           4        3.85
# 5      Rikitea -23.1203 -134.9692     77.29        74         100       12.80
# 6         Ahar  38.4774   47.0699     12.97        92          19        7.99
# 7        Airai  -8.9266  125.4092     60.64        93         100        3.40
# 8       Bethel  41.3712  -73.4140     16.03        79         100        8.01
# 9        Ejura   7.3856   -1.3562     87.40        16          98        4.61
#
#   Country Current Description
# 0      CA          light snow
# 1      US           clear sky
# 2      NA     overcast clouds
# 3      US     overcast clouds
# 4      ET           clear sky
# 5      PF          light rain
# 6      IR          few clouds
# 7      TL     overcast clouds
# 8      US                snow
# 9      GH     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Yellowknife      CA  62.4560 -114.3525     -4.59        85
# 1            Lompoc      US  34.6391 -120.4579     68.09        43
# 2             Opuwo      NA -18.0607   13.8400     73.80        36
# 3            Albany      US  42.6001  -73.9662     14.81        64
# 4             Ginir      ET   7.1333   40.7000     61.09        16
# ..              ...     ...      ...       ...       ...       ...
# 543  Kulhudhuffushi      MV   6.6221   73.0700     81.90        76
# 544      Launceston      AU -41.4500  147.1667     58.64        80
# 545          Touros      BR  -5.1989  -35.4608     83.30        73
# 546            Tura      IN  25.5198   90.2201     50.94        57
# 547   Qasigiannguit      GL  68.8193  -51.1922     14.25        82
#
#      Cloudiness  Wind Speed Current Description
# 0           100        5.75          light snow
# 1             0        5.75           clear sky
# 2           100       13.04     overcast clouds
# 3           100       10.00     overcast clouds
# 4             4        3.85           clear sky
# ..          ...         ...                 ...
# 543          62       18.52       broken clouds
# 544          40        1.01    scattered clouds
# 545         100       10.27     overcast clouds
# 546           0        2.19           clear sky
# 547          83       10.69       broken clouds
#
# [548 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
